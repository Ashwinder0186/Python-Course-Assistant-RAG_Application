# %%
import whisper
import json
import os



audios = os.listdir("audios")

# %%
model = whisper.load_model("base")

# %%
os.makedirs("jsons", exist_ok=True)

for audio in audios: 
    if "_" in audio:
        number = audio.split("_")[0]
        title = audio.split("_")[1][:-4]  # remove .mp3 from title
        print(number, title)

        result = model.transcribe(
            audio=f"audios/{audio}",
            language="hi",
            task="translate",
            word_timestamps=False
        )
        
        # Create chunks
        chunks = []
        for segment in result["segments"]:
            chunks.append({
                "number": number,
                "title": title,
                "start": segment["start"],
                "end": segment["end"],
                "text": segment["text"]
            })
        
        # Combine with full text
        chunks_with_metadata = {"chunks": chunks, "text": result["text"]}

        # Remove .mp3 extension from audio file for JSON filename
        audio_name_no_ext = os.path.splitext(audio)[0]
        json_path = f"jsons/{audio_name_no_ext}.json"

        # Save JSON
        with open(json_path, "w", encoding="utf-8") as f:
            json.dump(chunks_with_metadata, f, indent=2, ensure_ascii=False)
        
        print(f"✅ Saved JSON: {json_path}")
# Out:
# 10 Learn Python Episode 10 Boolean Operators.mp3
# ✅ Saved JSON: jsons/10_Learn Python Episode 10 Boolean Operators.mp3.json
# 11 Learn Python Episode 11 Lists (Arrays).mp3
# ✅ Saved JSON: jsons/11_Learn Python Episode 11 Lists (Arrays).mp3.json
# 12 Learn Python Episode 12 Dictionaries.mp3
# ✅ Saved JSON: jsons/12_Learn Python Episode 12 Dictionaries.mp3.json
# 13 Learn Python Episode 13 Variables.mp3
# ✅ Saved JSON: jsons/13_Learn Python Episode 13 Variables.mp3.json
# 14 Learn Python Episode 14 Builtin Functions.mp3
# ✅ Saved JSON: jsons/14_Learn Python Episode 14 Builtin Functions.mp3.json
# 15 Learn Python Episode 15 User-Defined Functions.mp3
# ✅ Saved JSON: jsons/15_Learn Python Episode 15 User-Defined Functions.mp3.json
# 16 Learn Python Episode 16 Adding Arguments to a Function.mp3
# ✅ Saved JSON: jsons/16_Learn Python Episode 16 Adding Arguments to a Function.mp3.json
# 17 Learn Python Episode 17 Default Arguments.mp3
# ✅ Saved JSON: jsons/17_Learn Python Episode 17 Default Arguments.mp3.json
# 18 Learn Python Episode 18 Keyword Arguments.mp3
# ✅ Saved JSON: jsons/18_Learn Python Episode 18 Keyword Arguments.mp3.json
# 19 Learn Python Episode 19 Infinite Arguments.mp3
# ✅ Saved JSON: jsons/19_Learn Python Episode 19 Infinite Arguments.mp3.json
# 1 Learn Python Episode 1 Introduction.mp3
# ✅ Saved JSON: jsons/1_Learn Python Episode 1 Introduction.mp3.json
# 20 Learn Python Episode 20 Return Values from Functions.mp3
# ✅ Saved JSON: jsons/20_Learn Python Episode 20 Return Values from Functions.mp3.json
# 21 Learn Python Episode 21 If, Elif, Else Statements.mp3
# ✅ Saved JSON: jsons/21_Learn Python Episode 21 If, Elif, Else Statements.mp3.json
# 22 Learn Python Episode 22 ForWhile Loops.mp3
# ✅ Saved JSON: jsons/22_Learn Python Episode 22 ForWhile Loops.mp3.json
# 23 Learn Python Episode 23 Importing Libraries into a Script.mp3
# ✅ Saved JSON: jsons/23_Learn Python Episode 23 Importing Libraries into a Script.mp3.json
# 24 Learn Python Episode 24 Final Project.mp3
# ✅ Saved JSON: jsons/24_Learn Python Episode 24 Final Project.mp3.json
# 2 Learn Python Episode 2 MacLinux Installation.mp3
# ✅ Saved JSON: jsons/2_Learn Python Episode 2 MacLinux Installation.mp3.json
# 3 Learn Python Episode 3 Windows 10 Installation.mp3
# ✅ Saved JSON: jsons/3_Learn Python Episode 3 Windows 10 Installation.mp3.json
# 4 Learn Python Episode 4 Interpreted vs Compiled Programming Languages.mp3
# ✅ Saved JSON: jsons/4_Learn Python Episode 4 Interpreted vs Compiled Programming Languages.mp3.json
# 5 Learn Python Episode 5 Creating and Running our First Script.mp3
# ✅ Saved JSON: jsons/5_Learn Python Episode 5 Creating and Running our First Script.mp3.json
# 6 Learn Python Episode 6 Choosing an IDE.mp3
# ✅ Saved JSON: jsons/6_Learn Python Episode 6 Choosing an IDE.mp3.json
# 7 Learn Python Episode 7 Numeric Types.mp3
# ✅ Saved JSON: jsons/7_Learn Python Episode 7 Numeric Types.mp3.json
# 8 Learn Python Episode 8 Strings.mp3
# ✅ Saved JSON: jsons/8_Learn Python Episode 8 Strings.mp3.json
# 9 Learn Python Episode 9 String Manipulation.mp3
# ✅ Saved JSON: jsons/9_Learn Python Episode 9 String Manipulation.mp3.json
