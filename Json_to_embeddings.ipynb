# %%
import requests
import os
import json
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import joblib

# %%
def create_embedding(text_list):
    # https://github.com/ollama/ollama/blob/main/docs/api.md#generate-embeddings
    r = requests.post("http://localhost:11434/api/embed", json={
        "model": "bge-m3",
        "input": text_list
    })

    embedding = r.json()["embeddings"] 
    return embedding


jsons = os.listdir("jsons") 
# List all the jsons 
#print(jsons)
my_dicts = []
chunk_id = 0

for json_file in jsons:
    with open(f"jsons/{json_file}") as f:
        content = json.load(f)
    print(f"Creating Embeddings for {json_file}")
    embeddings = create_embedding([c['text'] for c in content['chunks']])
       
    for i, chunk in enumerate(content['chunks']):
        chunk['chunk_id'] = chunk_id
        chunk['embedding'] = embeddings[i]
        chunk_id += 1
        my_dicts.append(chunk) 


df = pd.DataFrame.from_records(my_dicts)
# Save this dataframe
joblib.dump(df, 'embeddings.joblib')
# Out:
# Creating Embeddings for 10_Learn Python Episode 10 Boolean Operators.mp3.json
# Creating Embeddings for 11_Learn Python Episode 11 Lists (Arrays).mp3.json
# Creating Embeddings for 12_Learn Python Episode 12 Dictionaries.mp3.json
# Creating Embeddings for 13_Learn Python Episode 13 Variables.mp3.json
# Creating Embeddings for 14_Learn Python Episode 14 Builtin Functions.mp3.json
# Creating Embeddings for 15_Learn Python Episode 15 User-Defined Functions.mp3.json
# Creating Embeddings for 16_Learn Python Episode 16 Adding Arguments to a Function.mp3.json
# Creating Embeddings for 17_Learn Python Episode 17 Default Arguments.mp3.json
# Creating Embeddings for 18_Learn Python Episode 18 Keyword Arguments.mp3.json
# Creating Embeddings for 19_Learn Python Episode 19 Infinite Arguments.mp3.json
# Creating Embeddings for 1_Learn Python Episode 1 Introduction.mp3.json
# Creating Embeddings for 20_Learn Python Episode 20 Return Values from Functions.mp3.json
# Creating Embeddings for 21_Learn Python Episode 21 If, Elif, Else Statements.mp3.json
# Creating Embeddings for 22_Learn Python Episode 22 ForWhile Loops.mp3.json
# Creating Embeddings for 23_Learn Python Episode 23 Importing Libraries into a Script.mp3.json
# Creating Embeddings for 24_Learn Python Episode 24 Final Project.mp3.json
# Creating Embeddings for 2_Learn Python Episode 2 MacLinux Installation.mp3.json
# Creating Embeddings for 3_Learn Python Episode 3 Windows 10 Installation.mp3.json
# Creating Embeddings for 4_Learn Python Episode 4 Interpreted vs Compiled Programming Languages.mp3.json
# Creating Embeddings for 5_Learn Python Episode 5 Creating and Running our First Script.mp3.json
# Creating Embeddings for 6_Learn Python Episode 6 Choosing an IDE.mp3.json
# Creating Embeddings for 7_Learn Python Episode 7 Numeric Types.mp3.json
# Creating Embeddings for 8_Learn Python Episode 8 Strings.mp3.json
# Creating Embeddings for 9_Learn Python Episode 9 String Manipulation.mp3.json
# ['embeddings.joblib']
